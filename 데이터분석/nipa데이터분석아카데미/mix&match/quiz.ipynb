# %%
import os
os.listdir()
# Out:
# ['.config',
#  'seoul_df.csv',
#  'world_corona_201104.csv',
#  'seoul_info.csv',
#  'sample_data']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seoul_df=pd.read_csv('seoul_df.csv')
seoul_info=pd.read_csv('seoul_info.csv')
world_corona=pd.read_csv('world_corona_201104.csv')

# %%
#1
# inplace 할지 할당할지 말지 
world_corona=world_corona.drop(columns=['male_smokers'],axis=1)
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 0          AFG      Asia  ...           64.83                   0.498
# 1          AFG      Asia  ...           64.83                   0.498
# 2          AFG      Asia  ...           64.83                   0.498
# 3          AFG      Asia  ...           64.83                   0.498
# 4          AFG      Asia  ...           64.83                   0.498
# ...        ...       ...  ...             ...                     ...
# 53982      ZWE    Africa  ...           61.49                   0.535
# 53983      ZWE    Africa  ...           61.49                   0.535
# 53984      ZWE    Africa  ...           61.49                   0.535
# 53985      ZWE    Africa  ...           61.49                   0.535
# 53986      ZWE    Africa  ...           61.49                   0.535
#
# [53987 rows x 48 columns]

# %%
#2
world_corona.describe()
# Out:
#         total_cases      new_cases  ...  human_development_index         month
# count  5.038900e+04   53311.000000  ...             46889.000000  53987.000000
# mean   7.614745e+04     892.673838  ...                 0.722903      6.352140
# std    4.586467e+05    4998.455629  ...                 0.153185      2.597816
# min    1.000000e+00   -8261.000000  ...                 0.354000      1.000000
# 25%    1.520000e+02       0.000000  ...                 0.601000      4.000000
# 50%    1.903000e+03      13.000000  ...                 0.752000      6.000000
# 75%    1.876500e+04     205.000000  ...                 0.847000      9.000000
# max    9.383979e+06  101273.000000  ...                 0.953000     12.000000
#
# [8 rows x 45 columns]

# %%
#3
world_corona.column
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
# ...

# %%
#4
world_corona['is_valid']=1
world_corona['is_valid']

# %%
#5
world_corona[world_corona['location']=='France']
# Out:
#       iso_code continent  ... human_development_index is_valid
# 17478      FRA    Europe  ...                   0.901        1
# 17479      FRA    Europe  ...                   0.901        1
# 17480      FRA    Europe  ...                   0.901        1
# 17481      FRA    Europe  ...                   0.901        1
# 17482      FRA    Europe  ...                   0.901        1
# ...        ...       ...  ...                     ...      ...
# 17783      FRA    Europe  ...                   0.901        1
# 17784      FRA    Europe  ...                   0.901        1
# 17785      FRA    Europe  ...                   0.901        1
# 17786      FRA    Europe  ...                   0.901        1
# 17787      FRA    Europe  ...                   0.901        1
#
# [310 rows x 50 columns]

# %%
#6
seoul_info['지역']=seoul_info['시군구명_한글']
seoul_info.drop('시군구명_한글',axis=1,inplace=True)
pd.merge(seoul_df,seoul_info,on='지역',how='left')
# Out:
#         연번  확진달  확진일   환자번호  ...       시군구명_영문  ESRI_PK         위도          경도
# 0     5748   10   21  25530  ...  Yangcheon-gu     22.0  37.527062  126.856153
# 1     5747   10   21  25528  ...   Gangdong-gu     12.0  37.549208  127.146482
# 2     5746   10   21  25525  ...    Gangnam-gu      9.0  37.495985  127.066409
# 3     5745   10   21  25517  ...     Gwanak-gu     15.0  37.465399  126.943807
# 4     5744   10   21  25504  ...     Gwanak-gu     15.0  37.465399  126.943807
# ...    ...  ...  ...    ...  ...           ...      ...        ...         ...
# 5743     5    1   31      9  ...   Seongbuk-gu     17.0  37.606991  127.023218
# 5744     4    1   30      7  ...       Mapo-gu     14.0  37.562291  126.908780
# 5745     3    1   30      6  ...     Jongno-gu      6.0  37.599100  126.986149
# 5746     2    1   30      5  ...   Jungnang-gu      8.0  37.595379  127.093967
# 5747     1    1   24      2  ...    Gangseo-gu     10.0  37.565762  126.822656
#
# ...

# %%
#7

world_corona.sort_values('population',ascending=False)
# Out:
#       iso_code continent  ... human_development_index is_valid
# 10565      CHN      Asia  ...                   0.752        1
# 10679      CHN      Asia  ...                   0.752        1
# 10686      CHN      Asia  ...                   0.752        1
# 10685      CHN      Asia  ...                   0.752        1
# 10684      CHN      Asia  ...                   0.752        1
# ...        ...       ...  ...                     ...      ...
# 52549      VAT    Europe  ...                     NaN        1
# 52548      VAT    Europe  ...                     NaN        1
# 52547      VAT    Europe  ...                     NaN        1
# 52546      VAT    Europe  ...                     NaN        1
# 52527      VAT    Europe  ...                     NaN        1
#
# [53987 rows x 50 columns]

# %%
#8 

world_corona.drop_duplicates(subset=['location'],keep='last')
# Out:
#       iso_code continent           location  ... year_month  month  is_valid
# 309        AFG      Asia        Afghanistan  ...    2020-11     11         1
# 550        ALB    Europe            Albania  ...    2020-11     11         1
# 860        DZA    Africa            Algeria  ...    2020-11     11         1
# 1102       AND    Europe            Andorra  ...    2020-11     11         1
# 1330       AGO    Africa             Angola  ...    2020-11     11         1
# ...        ...       ...                ...  ...        ...    ...       ...
# 53124      WLF   Oceania  Wallis and Futuna  ...    2020-11     11         1
# 53317      ESH    Africa     Western Sahara  ...    2020-11     11         1
# 53526      YEM      Asia              Yemen  ...    2020-11     11         1
# 53757      ZMB    Africa             Zambia  ...    2020-11     11         1
# 53986      ZWE    Africa           Zimbabwe  ...    2020-11     11         1
#
# [213 rows x 52 columns]

# %%
#9

world_corona.groupby('location').sum()['new_cases']
# Out:
# location
# Afghanistan          41814.0
# Albania              21904.0
# Algeria              58979.0
# Andorra               4910.0
# Angola               11228.0
#                       ...
# Wallis and Futuna        1.0
# Western Sahara         766.0
# Yemen                 2067.0
# Zambia               16661.0
# Zimbabwe              8410.0
# Name: new_cases, Length: 213, dtype: float64

# %%
#10

len(world_corona['location'].unique())
# Out:
# 213

# %%
# 11

547857.0

# %%
# 12
51

# %%
#13

102900.0

# %%
# 14 14.8

# %%
# 15

Qatar

# %%
#16

seoul_df['접촉력'].value_counts().index[0]
# Out:
# '기타 확진자 접촉'

# %%
#17

region=seoul_df['지역'].value_counts()[0]/len(seoul_df['지역'])
print("{}".format(region*100),end='%\n')
# Out:
# 7.8636047320807245%

# %%
#18

month=seoul_df['확진달'].value_counts().index[0]
print("{}".format(month),end='월\n')
# Out:
# 8월

# %%
#19 

world_corona.groupby('continent')['new_deaths'].sum().sort_values().index[1]
# Out:
# 'Africa'

# %%
# 20

int(world_corona['new_deaths'].sum())
# Out:
# 1215706

# %%
# 14

# world_corona['date']=pd.to_datetime(world_corona['date'])
world_corona['year_month']=pd.to_datetime(world_corona['date']).dt.to_period('M')
group=world_corona.groupby(['year_month','location'],as_index=False)['new_cases'].sum()
group['year_month'][0]
pd.Period
# Out:
# Period('2019-12', 'M')

# %%
#21

data=world_corona[world_corona['location']=='French Polynesia']
data['iso_code'].unique()
# Out:
# array(['PYF'], dtype=object)

# %%
# 22

0.91

# %%
# 23

4.9

# %%
# 24

Italy

# %%
# 25
29.1%
# Out:
#   File "<ipython-input-155-37b8b0dbeaeb>", line 2
#     29.1%
#          ^
# SyntaxError: invalid syntax

# %%
#26 
2.0
# Out:
# 2.0

# %%
#27

data=world_corona.groupby('location')['new_cases'].sum().sort_values(ascending=False)[:10]

data.plot(kind='bar')

# %%
# 28

plt.plot(world_corona[world_corona['location']=='South Korea']['date'],world_corona[world_corona['location']=='South Korea']['new_cases'])

# %%
# 30

plt.plot(world_corona[world_corona['location']=='Japan']['date'],world_corona[world_corona['location']=='Japan']['new_cases'])
plt.plot(world_corona[world_corona['location']=='Japan']['date'],world_corona[world_corona['location']=='Japan']['total_cases'])

# %%
# 24

world_corona[world_corona['continent']=='Europe'].groupby('location')['new_deaths'].sum().sort_values(ascending=False)
#Italy
# Out:
# location
# United Kingdom            47250.0
# Italy                     39412.0
# France                    38289.0
# Spain                     36495.0
# Russia                    28828.0
# Belgium                   11947.0
# Germany                   10812.0
# Netherlands                7566.0
# Ukraine                    7532.0
# Romania                    7273.0
# Poland                     6102.0
# Sweden                     5969.0
# Czech Republic             3913.0
# Portugal                   2635.0
# Switzerland                2200.0
# Hungary                    2063.0
# Ireland                    1922.0
# Moldova                    1838.0
# Bulgaria                   1412.0
# Bosnia and Herzegovina     1317.0
# Austria                    1169.0
# Macedonia                  1049.0
# Belarus                     992.0
# Serbia                      844.0
# Denmark                     728.0
# Kosovo                      705.0
# Greece                      655.0
# ...

# %%
world_corona.groupby('location')['new_cases'].sum()
# Out:
# location
# Afghanistan          41814.0
# Albania              21904.0
# Algeria              58979.0
# Andorra               4910.0
# Angola               11228.0
#                       ...
# Wallis and Futuna        1.0
# Western Sahara         766.0
# Yemen                 2067.0
# Zambia               16661.0
# Zimbabwe              8410.0
# Name: new_cases, Length: 213, dtype: float64

# %%
#29

world_corona['month']=pd.to_datetime(world_corona['date']).dt.month
data=world_corona[(world_corona['month']!=11)&(world_corona['month']!=12)]
group=data.groupby('month')['new_cases'].sum()

group.plot()

# %%
# 14

world_corona['month']=pd.to_datetime(world_corona['date']).dt.month
world_corona['year']=pd.to_datetime(world_corona['date']).dt.year

world_corona.groupby(['year','month',''])['new_cases'].sum()

# %%
# 25

data=world_corona.groupby('location')['new_deaths'].sum()/world_corona.groupby('location')['new_cases'].sum()
data=pd.DataFrame(data)
data.reset_index().sort_values()
# Out:
#               location         0
# 0          Afghanistan  0.037021
# 1              Albania  0.024288
# 2              Algeria  0.033724
# 3              Andorra  0.015275
# 4               Angola  0.025739
# ..                 ...       ...
# 208  Wallis and Futuna  0.000000
# 209     Western Sahara  0.001305
# 210              Yemen  0.291243
# 211             Zambia  0.020947
# 212           Zimbabwe  0.029251
#
# [213 rows x 2 columns]

# %%
# 24 

data=world_corona[world_corona['continent']=='Europe']
data.groupby('location')['new_cases'].sum().sort_values(ascending=False)
# Out:
# location
# Russia                    1673686.0
# France                    1502763.0
# Spain                     1259366.0
# United Kingdom            1073882.0
# Italy                      759829.0
# Germany                    577593.0
# Belgium                    449012.0
# Poland                     414844.0
# Ukraine                    411093.0
# Netherlands                375444.0
# Czech Republic             362985.0
# Romania                    258437.0
# Switzerland                181660.0
# Portugal                   149443.0
# Sweden                     134532.0
# Austria                    118715.0
# Belarus                    101329.0
# Hungary                     90988.0
# Moldova                     77487.0
# Slovakia                    63556.0
# Ireland                     63048.0
# Bulgaria                    60537.0
# Croatia                     54087.0
# Bosnia and Herzegovina      53822.0
# Serbia                      51083.0
# Denmark                     49594.0
# ...
